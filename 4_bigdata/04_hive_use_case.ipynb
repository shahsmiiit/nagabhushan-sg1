# %% [markdown]
# # Lab: Hive (MapReduce) — Stocks Dataset (CLI)
#
# ## Goal
# Load the stocks dataset (nyse_data.txt) from the **master node local filesystem** into **HDFS**, create a **Hive table**, and compute the **Maximum close price for each stock symbol**.

# %% [markdown]
# ## Dataset location (local filesystem → master node)
#
# The dataset file will be present on the master node local filesystem (example):
# - `NYSE_Data.txt` (CSV file)

# %% [markdown]
# ## Copy data from local filesystem to HDFS
#
# #### Create the HDFS directory
#
# #### Copy the local dataset file into HDFS

# %% [markdown]
# ### Create database and table (Hive CLI)
#
# ### Table `stocks`
#
# - `stock_exchange STRING`
# - `stock_symbol STRING`
# - `date_of_trade STRING`
# - `open_price FLOAT`
# - `high_price FLOAT`
# - `low_price FLOAT`
# - `close_price FLOAT`
# - `volume BIGINT`
# - `adj_close_price FLOAT`
